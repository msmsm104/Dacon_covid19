# %% [markdown]
# <a href="https://colab.research.google.com/github/msmsm104/Dacon_covid19/blob/main/Preprocessing/mfcc/Data_preprocessing_1_0611(32).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Wav파일
#
#     - data frame에 feature로 표현.
#     - Dacon baseline 참조.

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 KB 3.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from librosa) (1.22.3)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 KB 1.8 MB/s eta 0:00:00
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-macosx_10_5_x86_64.macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.whl (613 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.4/613.4 KB 12.5 MB/s eta 0:00:000:00:01
# Requirement already satisfied: decorator>=4.0.10 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: joblib>=0.14 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from librosa) (1.1.0)
# Collecting numba>=0.45.1
#   Downloading numba-0.55.2-cp38-cp38-macosx_10_14_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 27.1 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 KB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting audioread>=2.1.5
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.5/377.5 KB 8.2 MB/s eta 0:00:000:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20.0 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from librosa) (21.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from librosa) (1.8.0)
# Requirement already satisfied: setuptools in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from numba>=0.45.1->librosa) (61.3.1)
# Collecting llvmlite<0.39,>=0.38.0rc1
#   Downloading llvmlite-0.38.1-cp38-cp38-macosx_10_9_x86_64.whl (25.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 8.9 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from packaging>=20.0->librosa) (3.0.7)
# Requirement already satisfied: requests>=2.19.0 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from pooch>=1.0->librosa) (2.27.1)
# Collecting appdirs>=1.3.0
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: six>=1.3 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moonseokmin/miniforge3/envs/krc/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.5.18.1)
# Building wheels for collected packages: audioread, resampy
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23153 sha256=4ebe31351f84206e9a649b42956f639683b145d6bb057f297e9c2c45cc45e5b4
#   Stored in directory: /Users/moonseokmin/Library/Caches/pip/wheels/49/5a/e4/df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320732 sha256=78e6c48a58f47074caeb5984b849cb2f6660e33f075bc47d370c065c1f677daa
#   Stored in directory: /Users/moonseokmin/Library/Caches/pip/wheels/6f/d1/5d/f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
# Successfully built audioread resampy
# Installing collected packages: audioread, appdirs, llvmlite, soundfile, pooch, numba, resampy, librosa
# Successfully installed appdirs-1.4.4 audioread-2.1.9 librosa-0.9.1 llvmlite-0.38.1 numba-0.55.2 pooch-1.6.0 resampy-0.2.2 soundfile-0.10.3.post1

# %% [markdown]
# ### Import

# %%
import random
import pandas as pd
import numpy as np
import os
import librosa

from tqdm.auto import tqdm

from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import OneHotEncoder

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### Hyper parameter Setting

# %%
CFG = {
    'SR':16000,
    'N_MFCC':32, # MFCC 벡터를 추출할 개수
    'SEED':41
}

# %% [markdown]
# ### Fixed Random Seed

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(CFG['SEED']) # Seed 고정

# %% [markdown]
# ### Data Preprocessing_1

# %%
train_df = pd.read_csv('./Raw/open/train_data.csv')
test_df = pd.read_csv('./Raw/open/test_data.csv')

# %%
def get_mfcc_feature(df, data_type, save_path):
    # Data Folder path
    root_folder = './Raw/open'
    if os.path.exists(save_path):
        print(f'{save_path} is exist.')
        return
    features = []
    for uid in tqdm(df['id']):
        root_path = os.path.join(root_folder, data_type)
        path = os.path.join(root_path, str(uid).zfill(5)+'.wav')

        # librosa패키지를 사용하여 wav 파일 load
        y, sr = librosa.load(path, sr=CFG['SR'])
        
        # librosa패키지를 사용하여 mfcc 추출
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=CFG['N_MFCC'])

        y_feature = []
        # 추출된 MFCC들의 평균을 Feature로 사용
        for e in mfcc:
            y_feature.append(np.mean(e))
        features.append(y_feature)
    
    # 기존의 자가진단 정보를 담은 데이터프레임에 추출된 오디오 Feature를 추가
    mfcc_df = pd.DataFrame(features, columns=['mfcc_'+str(x) for x in range(1,CFG['N_MFCC']+1)])
    df = pd.concat([df, mfcc_df], axis=1)
    df.to_csv(save_path, index=False)
    print('Done.')

# %%
get_mfcc_feature(train_df, 'train', './train_mfcc_data.csv')
get_mfcc_feature(test_df, 'test', './test_mfcc_data.csv')
# Out:
#   0%|          | 0/3805 [00:00<?, ?it/s]
# Done.
#   0%|          | 0/5732 [00:00<?, ?it/s]
# Done.

# %%
train_df_2 = pd.read_csv('./train_mfcc_data.csv')
test_df_2 = pd.read_csv('./test_mfcc_data.csv')

# %%
train_df_2
# Out:
#         id  age  gender  respiratory_condition  fever_or_muscle_pain  covid19  \
# 0        1   24  female                      0                     1        0
# 1        2   51    male                      0                     0        0
# 2        3   22    male                      0                     0        0
# 3        4   29  female                      1                     0        0
# 4        5   23    male                      0                     0        0
# ...    ...  ...     ...                    ...                   ...      ...
# 3800  3801   53    male                      0                     0        0
# 3801  3802   25    male                      0                     0        0
# 3802  3803   26  female                      0                     0        0
# 3803  3804   27  female                      0                     0        0
# 3804  3805   49  female                      1                     1        0
#
#          mfcc_1     mfcc_2     mfcc_3     mfcc_4  ...   mfcc_23   mfcc_24  \
# 0    -274.93472  29.345425 -19.152718  -7.836880  ... -2.320942  2.150005
# 1    -311.56317  52.478150  -0.098957 -11.070889  ... -6.494778  0.545812
# 2    -438.29000  46.588910 -22.689060  -3.607528  ... -0.156510 -1.682014
# 3    -368.42610  46.939358  -7.443123  -3.694383  ... -0.155855  3.839285
# 4    -535.19446   7.165523  -7.422007   2.231186  ... -0.144311 -0.413284
# ...         ...        ...        ...        ...  ...       ...       ...
# 3800 -328.48767  68.190380 -40.383747   2.297682  ... -0.168663  1.255295
# 3801 -386.25732  73.931350 -12.114974  -0.500643  ... -2.914732  4.907058
# 3802 -347.20593  58.544130  12.969809  27.973340  ... -2.396356 -2.741529
# 3803 -179.11195  70.697860 -14.571251 -10.143574  ... -7.733275  5.680011
# 3804 -308.60490  85.642650  11.310870  12.702833  ...  0.253423  4.049770
#
#        mfcc_25   mfcc_26   mfcc_27   mfcc_28   mfcc_29   mfcc_30   mfcc_31  \
# 0    -0.925417  2.116030 -0.192730  2.417784 -4.736650  1.237788 -1.600426
# 1    -6.261986 -2.384403 -6.743353  0.255105 -0.966994 -2.113054 -2.433555
# 2     2.618637  1.244486 -0.074025 -0.964130 -0.735731 -0.420304  0.795621
# 3    -2.503368  2.750743  1.758510  2.094587  0.295868  1.737648 -0.654136
# 4    -1.452623  0.235582 -0.973687  0.777570 -0.735323  1.141641 -0.497988
# ...        ...       ...       ...       ...       ...       ...       ...
# 3800 -4.972386 -0.053485  1.204618  3.961083 -4.195477  2.746365 -4.138545
# 3801  1.142662  6.096552  2.885290  3.611389 -0.631856  3.847093  2.540035
# 3802 -2.629161 -1.906816 -3.183893 -1.446224 -0.021817 -1.601471 -1.630300
# 3803 -2.057645  1.684632 -1.205147 -0.134177 -4.729319  0.557955 -5.249906
# 3804 -1.274498 -3.732056  1.210951  3.166944  1.470234  1.192790  0.210758
#
#        mfcc_32
# 0    -1.462419
# 1     0.881178
# 2     0.411339
# 3     1.847976
# 4     1.190929
# ...        ...
# 3800 -2.572868
# 3801  5.938597
# 3802 -1.382297
# 3803 -0.278406
# 3804  4.186349
#
# [3805 rows x 38 columns]

# %%
test_df_2
# Out:
#         id  age  gender  respiratory_condition  fever_or_muscle_pain  \
# 0     3806   48  female                      1                     0
# 1     3807   24  female                      0                     0
# 2     3808   29    male                      0                     0
# 3     3809   39  female                      0                     0
# 4     3810   34    male                      0                     0
# ...    ...  ...     ...                    ...                   ...
# 5727  9533   43    male                      0                     0
# 5728  9534   48  female                      0                     1
# 5729  9535   44  female                      0                     0
# 5730  9536   25  female                      0                     0
# 5731  9537   17  female                      1                     1
#
#           mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5  ...   mfcc_23  \
# 0     -619.98790   9.328649   0.821094   2.373343 -0.171163  ... -0.313271
# 1     -493.60570   8.492651  -2.758263  -2.801817 -2.770232  ... -0.677968
# 2    -1058.92520  -2.354820  -7.397019  -0.686011 -5.422640  ... -0.005907
# 3     -362.16165  27.119738  -9.231675   9.747519 -1.013352  ... -3.150050
# 4     -387.59268  45.165874 -14.454832  -2.965205 -9.931789  ... -4.803989
# ...          ...        ...        ...        ...       ...  ...       ...
# 5727  -363.31592  48.014732   6.568864  11.673552 -7.893135  ... -2.381601
# 5728  -650.22455   2.844074   2.063639   5.160135 -4.574105  ... -1.014055
# 5729  -335.09128  54.100250 -15.533144  13.702870 -9.206227  ... -2.222737
# 5730  -534.98730  17.522040  -9.687601   5.585782 -8.310497  ... -1.565546
# 5731  -298.90560  84.170860   3.985836   8.882576 -5.539370  ... -2.250323
#
#        mfcc_24   mfcc_25   mfcc_26   mfcc_27   mfcc_28   mfcc_29   mfcc_30  \
# 0    -0.053711 -0.029855  0.043562 -0.405293 -0.246975 -0.110937  0.019196
# 1    -0.643835 -0.822677 -0.113844 -1.210391  0.273594 -0.685921  0.440101
# 2     3.130717  2.591598  0.466579 -0.126740  1.610208 -3.389459 -2.868738
# 3    -0.271802  0.034901  0.414227 -2.836006  0.105023  0.518484  2.139494
# 4    -3.594219  0.289146 -5.298121  1.614137  3.108044 -5.373443  0.106868
# ...        ...       ...       ...       ...       ...       ...       ...
# 5727  1.899532  1.335172 -0.633322  1.076864 -1.657736 -5.816984 -1.341339
# 5728  0.853542 -0.998176  0.421669 -0.817565  1.201457 -1.148051  0.335183
# 5729 -2.004309 -2.250272 -1.290327 -2.485475 -1.268755 -4.346352  0.055307
# 5730 -1.021776 -1.453681 -1.553367 -1.581636 -1.428654 -1.613187 -0.816451
# 5731 -1.542222 -4.565392  0.959756 -5.595184  0.134770 -3.737429 -2.413115
#
#        mfcc_31   mfcc_32
# 0    -0.155829 -0.130705
# 1    -0.960277  0.371881
# 2    -1.301445 -2.902404
# 3     0.944032  1.029428
# 4     2.054100 -1.994548
# ...        ...       ...
# 5727 -1.719530 -0.579730
# 5728  0.076959 -0.215559
# 5729 -1.181318  0.464578
# 5730 -0.766406  0.130751
# 5731 -0.334233 -0.072389
#
# [5732 rows x 37 columns]
